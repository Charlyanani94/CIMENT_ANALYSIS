# %% [markdown]
# ## TP 1 ANANI CHARLY   //          AGOSSOU MENDEL     //         HOUNTON SYLVESTRE

# %% [markdown]
# 1. Prétraitement des données :
# o Identifier et traiter les valeurs manquantes et les données bruitées.
# o Supprimer les colonnes inutiles ou présentant des valeurs constantes.
# o Réaliser une transformation des variables pour standardiser l’ensemble des
# données.
